# %% [markdown]
# [![Open in Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://www.kaggle.com/kernels/welcome?src=https://github.com/Code-the-Dream-School/python-200/blob/main/lessons/nn_lesson_template/resources/sample_notebook.ipynb)

# %% [markdown]
# # Sample notebook
# Sample notebook for Python 200 to illustrate how to include notebooks in lessons.
#
# Crucial point for jupyter notebooks:
#
# Always clear outputs before committing changes. You can do this with the following command before commiting:
#
#     `jupyter nbconvert --clear-output --inplace path-to-nb.ipynb`

# %% [markdown]
# # code cell
# 1+1=2
